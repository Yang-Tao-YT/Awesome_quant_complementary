# %% [markdown]
# # Enjoy

# %%
import numpy as np
from numpy.random import choice
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_datareader import data as pdr
import yfinance as yf

import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()

# %%
df = pdr.get_data_yahoo("AAPL", start="2020-01-01" , end = '2021-01-01').reset_index()

# %%
class Agent:

    LEARNING_RATE = 1e-4
    LAYER_SIZE = 256
    GAMMA = 0.9
    OUTPUT_SIZE = 3

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.X = tf.placeholder(tf.float32, (None, self.state_size))
        self.REWARDS = tf.placeholder(tf.float32, (None))
        self.ACTIONS = tf.placeholder(tf.int32, (None))
        feed_forward = tf.layers.dense(self.X, self.LAYER_SIZE, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, self.OUTPUT_SIZE, activation = tf.nn.softmax)
        input_y = tf.one_hot(self.ACTIONS, self.OUTPUT_SIZE)
        loglike = tf.log((input_y * (input_y - self.logits) + (1 - input_y) * (input_y + self.logits)) + 1)
        rewards = tf.tile(tf.reshape(self.REWARDS, (-1,1)), [1, self.OUTPUT_SIZE])
        self.cost = -tf.reduce_mean(loglike * (rewards + 1)) 
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.LEARNING_RATE).minimize(self.cost)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def predict(self, inputs):
        return self.sess.run(self.logits, feed_dict={self.X:inputs})
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def discount_rewards(self, r):
        discounted_r = np.zeros_like(r)
        running_add = 0
        for t in reversed(range(0, r.size)):
            running_add = running_add * self.GAMMA + r[t]
            discounted_r[t] = running_add
        return discounted_r
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.get_predicted_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            ep_history = []
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.get_predicted_action(state)
                next_state = self.get_state(t + 1)
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= close[t]
                
                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                ep_history.append([state,action,starting_money,next_state])
                state = next_state
            ep_history = np.array(ep_history)
            ep_history[:,2] = self.discount_rewards(ep_history[:,2])
            cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict={self.X:np.vstack(ep_history[:,0]),
                                                    self.REWARDS:ep_history[:,2],
                                                    self.ACTIONS:ep_history[:,1]})
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
agent = Agent(state_size = window_size,
             window_size = window_size,
             trend = close,
             skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# /Users/yangtao/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py:1751: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: 74.864998.3, cost: -19901.591797, total money: 10074.864998
# epoch: 20, total rewards: 49.587490.3, cost: -21555.865234, total money: 10049.587490
# epoch: 30, total rewards: 11.594994.3, cost: -22988.740234, total money: 10011.594994
# epoch: 40, total rewards: 213.215008.3, cost: -24098.417969, total money: 10213.215008
# epoch: 50, total rewards: 121.540020.3, cost: -25230.970703, total money: 10121.540020
# epoch: 60, total rewards: 25.302509.3, cost: -26075.416016, total money: 10025.302509
# epoch: 70, total rewards: 46.370007.3, cost: -26912.457031, total money: 10046.370007
# epoch: 80, total rewards: 121.620022.3, cost: -27801.072266, total money: 10121.620022
# epoch: 90, total rewards: 167.627525.3, cost: -28586.417969, total money: 10167.627525
# epoch: 100, total rewards: 409.425018.3, cost: -28881.628906, total money: 10409.425018
# epoch: 110, total rewards: 120.350052.3, cost: -29724.052734, total money: 10120.350052
# epoch: 120, total rewards: 590.467552.3, cost: -28696.179688, total money: 10590.467552
# epoch: 130, total rewards: 164.497528.3, cost: -30398.882812, total money: 10164.497528
# epoch: 140, total rewards: 160.097488.3, cost: -30383.789062, total money: 9684.677490
# epoch: 150, total rewards: 503.589970.3, cost: -29183.908203, total money: 9435.729969
# epoch: 160, total rewards: 249.347527.3, cost: -30809.154297, total money: 9650.987526
# epoch: 170, total rewards: 392.164978.3, cost: -30898.998047, total money: 9675.774979
# epoch: 180, total rewards: 104.317486.3, cost: -32158.804688, total money: 10104.317486
# epoch: 190, total rewards: 432.790001.3, cost: -29751.080078, total money: 8417.860008
# epoch: 200, total rewards: 319.099960.3, cost: -31285.199219, total money: 10319.099960

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 6: buy 1 unit at price 77.582497, total balance 9922.417503
# day 7, sell 1 unit at price 79.239998, investment 2.136437 %, total balance 10001.657501,
# day 8: buy 1 unit at price 78.169998, total balance 9923.487503
# day 9: buy 1 unit at price 77.834999, total balance 9845.652504
# day 13: buy 1 unit at price 79.425003, total balance 9766.227501
# day 15: buy 1 unit at price 79.577499, total balance 9686.650002
# day 17, sell 1 unit at price 79.422501, investment 1.602280 %, total balance 9766.072502,
# day 19, sell 1 unit at price 80.967499, investment 4.024539 %, total balance 9847.040001,
# day 20, sell 1 unit at price 77.377502, investment -2.577904 %, total balance 9924.417503,
# day 22, sell 1 unit at price 79.712502, investment 0.169649 %, total balance 10004.130005,
# day 25: buy 1 unit at price 80.007500, total balance 9924.122505
# day 26: buy 1 unit at price 80.387497, total balance 9843.735008
# day 27: buy 1 unit at price 79.902496, total balance 9763.832512
# day 28: buy 1 unit at price 81.800003, total balance 9682.032509
# day 29, sell 1 unit at price 81.217499, investment 1.512357 %, total balance 9763.250008,
# day 30: buy 1 unit at price 81.237503, total balance 9682.012505
# day 32, sell 1 unit at price 80.904999, investment 0.643759 %, total balance 9762.917503,
# day 33: buy 1 unit at price 80.074997, total balance 9682.842506
# day 34, sell 1 unit at price 78.262497, investment -2.052501 %, total balance 9761.105003,
# day 35: buy 1 unit at price 74.544998, total balance 9686.560005
# day 36, sell 1 unit at price 72.019997, investment -11.955998 %, total balance 9758.580002,
# day 37: buy 1 unit at price 73.162498, total balance 9685.417503
# day 38, sell 1 unit at price 68.379997, investment -15.827057 %, total balance 9753.797501,
# day 40, sell 1 unit at price 74.702499, investment -6.709332 %, total balance 9828.500000,
# day 43: buy 1 unit at price 73.230003, total balance 9755.269997
# day 44, sell 1 unit at price 72.257500, investment -3.068614 %, total balance 9827.527496,
# day 45: buy 1 unit at price 66.542503, total balance 9760.984993
# day 48, sell 1 unit at price 62.057499, investment -15.178541 %, total balance 9823.042492,
# day 50, sell 1 unit at price 60.552502, investment -17.311896 %, total balance 9883.594994,
# day 51, sell 1 unit at price 63.215000, investment -5.000568 %, total balance 9946.809994,
# day 57: buy 1 unit at price 61.380001, total balance 9885.429993
# day 58, sell 1 unit at price 64.610001, investment 5.262300 %, total balance 9950.039993,
# day 60: buy 1 unit at price 63.702499, total balance 9886.337494
# day 61, sell 1 unit at price 63.572498, investment -0.204075 %, total balance 9949.909992,
# day 62: buy 1 unit at price 60.227501, total balance 9889.682491
# day 65, sell 1 unit at price 65.617500, investment 8.949399 %, total balance 9955.299992,
# day 74: buy 1 unit at price 69.232498, total balance 9886.067493
# day 77: buy 1 unit at price 68.757500, total balance 9817.309994
# day 79, sell 1 unit at price 70.792503, investment 2.253285 %, total balance 9888.102497,
# day 81: buy 1 unit at price 71.932503, total balance 9816.169994
# day 82, sell 1 unit at price 73.449997, investment 6.824706 %, total balance 9889.619991,
# day 84, sell 1 unit at price 73.290001, investment 1.887183 %, total balance 9962.909992,
# day 90: buy 1 unit at price 77.852501, total balance 9885.057491
# day 91, sell 1 unit at price 76.912498, investment -1.207415 %, total balance 9961.969990,
# day 92: buy 1 unit at price 77.385002, total balance 9884.584988
# day 94: buy 1 unit at price 78.739998, total balance 9805.844990
# day 99: buy 1 unit at price 79.182503, total balance 9726.662487
# day 102, sell 1 unit at price 79.485001, investment 2.713702 %, total balance 9806.147488,
# day 103: buy 1 unit at price 80.462502, total balance 9725.684986
# day 104, sell 1 unit at price 80.834999, investment 2.660657 %, total balance 9806.519985,
# day 105, sell 1 unit at price 81.279999, investment 2.648939 %, total balance 9887.799984,
# day 106: buy 1 unit at price 80.580002, total balance 9807.219982
# day 107, sell 1 unit at price 82.875000, investment 2.998289 %, total balance 9890.094982,
# day 108, sell 1 unit at price 83.364998, investment 3.456188 %, total balance 9973.459980,
# day 111: buy 1 unit at price 83.974998, total balance 9889.484982
# day 113, sell 1 unit at price 85.747498, investment 2.110746 %, total balance 9975.232479,
# day 114: buy 1 unit at price 88.019997, total balance 9887.212482
# day 115, sell 1 unit at price 87.897499, investment -0.139170 %, total balance 9975.109982,
# day 117: buy 1 unit at price 87.430000, total balance 9887.679981
# day 118: buy 1 unit at price 89.717499, total balance 9797.962482
# day 120: buy 1 unit at price 90.014999, total balance 9707.947483
# day 121: buy 1 unit at price 91.209999, total balance 9616.737484
# day 124, sell 1 unit at price 91.199997, investment 4.312017 %, total balance 9707.937481,
# day 125: buy 1 unit at price 91.027496, total balance 9616.909985
# day 127, sell 1 unit at price 93.462502, investment 4.174217 %, total balance 9710.372486,
# day 130, sell 1 unit at price 95.752502, investment 6.373941 %, total balance 9806.124989,
# day 131: buy 1 unit at price 95.919998, total balance 9710.204990
# day 132: buy 1 unit at price 95.477501, total balance 9614.727489
# day 133: buy 1 unit at price 97.057503, total balance 9517.669987
# day 135: buy 1 unit at price 96.522499, total balance 9421.147488
# day 136, sell 1 unit at price 96.327499, investment 5.610679 %, total balance 9517.474987,
# day 139: buy 1 unit at price 97.272499, total balance 9420.202488
# day 140, sell 1 unit at price 92.845001, investment 1.996655 %, total balance 9513.047489,
# day 143, sell 1 unit at price 93.252502, investment -2.780959 %, total balance 9606.299992,
# day 144: buy 1 unit at price 95.040001, total balance 9511.259991
# day 145, sell 1 unit at price 96.190002, investment 0.746251 %, total balance 9607.449993,
# day 147, sell 1 unit at price 108.937500, investment 12.240164 %, total balance 9716.387493,
# day 148: buy 1 unit at price 109.665001, total balance 9606.722492
# day 149: buy 1 unit at price 110.062500, total balance 9496.659992
# day 150, sell 1 unit at price 113.902496, investment 18.006162 %, total balance 9610.562489,
# day 151, sell 1 unit at price 111.112503, investment 14.228075 %, total balance 9721.674992,
# day 152, sell 1 unit at price 112.727501, investment 18.610585 %, total balance 9834.402493,
# day 153: buy 1 unit at price 109.375000, total balance 9725.027493
# day 154, sell 1 unit at price 113.010002, investment 3.050199 %, total balance 9838.037495,
# day 155: buy 1 unit at price 115.010002, total balance 9723.027493
# day 156, sell 1 unit at price 114.907501, investment 4.402045 %, total balance 9837.934994,
# day 158, sell 1 unit at price 115.562500, investment 5.657143 %, total balance 9953.497494,
# day 159, sell 1 unit at price 115.707497, investment 0.606464 %, total balance 10069.204990,
# day 160: buy 1 unit at price 118.275002, total balance 9950.929989
# day 161: buy 1 unit at price 124.370003, total balance 9826.559986
# day 162: buy 1 unit at price 125.857498, total balance 9700.702488
# day 163, sell 1 unit at price 124.824997, investment 5.537937 %, total balance 9825.527485,
# day 164: buy 1 unit at price 126.522499, total balance 9699.004986
# day 166: buy 1 unit at price 124.807503, total balance 9574.197483
# day 167, sell 1 unit at price 129.039993, investment 3.754917 %, total balance 9703.237476,
# day 168: buy 1 unit at price 134.179993, total balance 9569.057484
# day 170, sell 1 unit at price 120.879997, investment -3.954870 %, total balance 9689.937481,
# day 173: buy 1 unit at price 117.320000, total balance 9572.617481
# day 174: buy 1 unit at price 113.489998, total balance 9459.127483
# day 176, sell 1 unit at price 115.360001, investment -8.822540 %, total balance 9574.487484,
# day 178, sell 1 unit at price 112.129997, investment -10.157647 %, total balance 9686.617481,
# day 179, sell 1 unit at price 110.339996, investment -17.767177 %, total balance 9796.957478,
# day 180: buy 1 unit at price 106.839996, total balance 9690.117481
# day 181, sell 1 unit at price 110.080002, investment -6.171154 %, total balance 9800.197483,
# day 182, sell 1 unit at price 111.809998, investment -1.480307 %, total balance 9912.007481,
# day 186, sell 1 unit at price 114.959999, investment 7.600153 %, total balance 10026.967480,
# day 190: buy 1 unit at price 113.019997, total balance 9913.947483
# day 191: buy 1 unit at price 116.500000, total balance 9797.447483
# day 192: buy 1 unit at price 113.160004, total balance 9684.287479
# day 193, sell 1 unit at price 115.080002, investment 1.822691 %, total balance 9799.367481,
# day 194, sell 1 unit at price 114.970001, investment -1.313304 %, total balance 9914.337482,
# day 195: buy 1 unit at price 116.970001, total balance 9797.367481
# day 196, sell 1 unit at price 124.400002, investment 9.932836 %, total balance 9921.767483,
# day 198, sell 1 unit at price 121.190002, investment 3.607764 %, total balance 10042.957485,
# day 201: buy 1 unit at price 115.980003, total balance 9926.977482
# day 202: buy 1 unit at price 117.510002, total balance 9809.467480
# day 204, sell 1 unit at price 115.750000, investment -0.198313 %, total balance 9925.217480,
# day 205, sell 1 unit at price 115.040001, investment -2.101950 %, total balance 10040.257481,
# day 206: buy 1 unit at price 115.050003, total balance 9925.207478
# day 207, sell 1 unit at price 116.599998, investment 1.347236 %, total balance 10041.807476,
# day 208: buy 1 unit at price 111.199997, total balance 9930.607479
# day 209: buy 1 unit at price 115.320000, total balance 9815.287479
# day 212, sell 1 unit at price 110.440002, investment -0.683448 %, total balance 9925.727482,
# day 214: buy 1 unit at price 119.029999, total balance 9806.697483
# day 215, sell 1 unit at price 118.690002, investment 2.922306 %, total balance 9925.387486,
# day 218: buy 1 unit at price 119.489998, total balance 9805.897488
# day 221, sell 1 unit at price 120.300003, investment 1.066962 %, total balance 9926.197491,
# day 222: buy 1 unit at price 119.389999, total balance 9806.807491
# day 223: buy 1 unit at price 118.029999, total balance 9688.777493
# day 224: buy 1 unit at price 118.639999, total balance 9570.137493
# day 225, sell 1 unit at price 117.339996, investment -1.799315 %, total balance 9687.477489,
# day 226, sell 1 unit at price 113.849998, investment -4.640255 %, total balance 9801.327488,
# day 227, sell 1 unit at price 115.169998, investment -2.423113 %, total balance 9916.497486,
# day 228: buy 1 unit at price 116.029999, total balance 9800.467487
# day 229, sell 1 unit at price 116.589996, investment -1.727919 %, total balance 9917.057484,
# day 230: buy 1 unit at price 119.050003, total balance 9798.007481
# day 231, sell 1 unit at price 122.720001, investment 5.765752 %, total balance 9920.727482,
# day 232: buy 1 unit at price 123.080002, total balance 9797.647480
# day 233: buy 1 unit at price 122.940002, total balance 9674.707478
# day 234, sell 1 unit at price 122.250000, investment 2.687944 %, total balance 9796.957478,
# day 235, sell 1 unit at price 123.750000, investment 0.544360 %, total balance 9920.707478,
# day 237, sell 1 unit at price 121.779999, investment -0.943553 %, total balance 10042.487476,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains: {:.2f} on AAPL in period from 2019-01-01 to 2021-01-01, total investment gain:{:.2%}'.format(total_gains, invest/100))


plt.legend()
plt.show()
